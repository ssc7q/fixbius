# %%
##demonstrate result of working function biusQuaternionCalc() in fixed-point arithmetic

# %%
Q = []
t = []
i=0
with open("c:/download/fix.txt", "r") as f:
    for line in f.readlines():
        l=list(map(float, line.split()))
        Q.append(l)
        t.append(i)
        i=i+1

# %%
import matplotlib.pyplot as pp
# %matplotlib inline

# %%
fig, ax = pp.subplots(figsize=(15,10))

ax.plot(t[:19100],Q[:19100])
ax.grid(True)
